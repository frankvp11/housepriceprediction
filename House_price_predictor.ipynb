# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

test_df = pd.read_csv("/content/sample_data/california_housing_test.csv")
df["median_house_value"] = df["median_house_value"].astype(int)
df
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936               66900
# 1        -114.47     34.40  ...         1.8200               80100
# 2        -114.56     33.69  ...         1.6509               85700
# 3        -114.57     33.64  ...         3.1917               73400
# 4        -114.57     33.57  ...         1.9250               65500
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571              111400
# 16996    -124.27     40.69  ...         2.5179               79000
# 16997    -124.30     41.84  ...         3.0313              103600
# 16998    -124.30     41.80  ...         1.9797               85800
# 16999    -124.35     40.54  ...         3.0147               94600
#
# [17000 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
features = df[["housing_median_age", "total_rooms", "total_bedrooms", "households", "median_income", "longitude", "latitude"]]
y_vals = df[["median_house_value"]]
regr.fit(features, y_vals)
# Out:
# LinearRegression()

# %%
test_df
features2 = test_df[["housing_median_age", "total_rooms", "total_bedrooms", "households", "median_income", "longitude", "latitude"]]
y_vals2 = test_df[["median_house_value"]]

# %%
predictions = regr.predict(features2)

# %%
test_df["predictions"] = predictions

# %%
test_df
# Out:
#       longitude  latitude  ...  median_house_value    predictions
# 0       -122.05     37.37  ...            344700.0  349596.217252
# 1       -118.30     34.26  ...            176500.0  210969.635945
# 2       -117.81     33.78  ...            270500.0  267721.509371
# 3       -118.36     33.82  ...            330000.0  315138.149445
# 4       -119.67     36.33  ...             81700.0  122288.183323
# ...         ...       ...  ...                 ...            ...
# 2995    -119.86     34.42  ...            225000.0  176662.504669
# 2996    -118.14     34.06  ...            237200.0  198298.330253
# 2997    -119.70     36.30  ...             62000.0   84441.218604
# 2998    -117.12     34.10  ...            162500.0  140892.895762
# 2999    -119.63     34.42  ...            500001.0  461750.741700
#
# [3000 rows x 10 columns]

# %%
regr.score(features2, y_vals2)
# Out:
# 0.5997048567781794

# %%
import matplotlib.pyplot as plt
plt.plot(test_df.index[:100], test_df.median_house_value[:100])
plt.plot(test_df.index[:100], predictions[:100])
plt.show
# Out:
# <function matplotlib.pyplot.show>
